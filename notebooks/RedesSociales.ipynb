# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
data = {
    'Fecha': pd.date_range(start='2023-01-01', periods=100,freq='D'),
    'Usuario': np.random.choice(['Usuario1','Usuario2','Usuario3','Usuario4','Usuario5'],size=100),
    'Tweet': np.random.choice([
        'I love Pandas for data analysis','python is awesome','Just finished a great workout','Pandas makes data manipulation easy','Data science is fascinating'],size=100)
}

df = pd.DataFrame(data)
display(df)
# Out:
#         Fecha   Usuario                                Tweet
# 0  2023-01-01  Usuario3          Data science is fascinating
# 1  2023-01-02  Usuario1          Data science is fascinating
# 2  2023-01-03  Usuario5                    python is awesome
# 3  2023-01-04  Usuario1  Pandas makes data manipulation easy
# 4  2023-01-05  Usuario5          Data science is fascinating
# ..        ...       ...                                  ...
# 95 2023-04-06  Usuario1          Data science is fascinating
# 96 2023-04-07  Usuario3                    python is awesome
# 97 2023-04-08  Usuario3        Just finished a great workout
# 98 2023-04-09  Usuario4          Data science is fascinating
# 99 2023-04-10  Usuario3                    python is awesome
#
# [100 rows x 3 columns]

# %%
all_tweets = ' '.join(df['Tweet'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_tweets)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud de los Tweets')
plt.show()

# %%
#Tendencias de los tweets
tweets_por_dia = df['Fecha'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
tweets_por_dia.plot(kind='line', color='skyblue', marker='o')
plt.title('Tendencias de los Tweets')
plt.xlabel('Fecha')
plt.ylabel('Numero de Tweets')
plt.grid(True)
plt.show()

# %%
tweets_por_usuario = df['Usuario'].value_counts()
plt.figure(figsize=(10, 6))
tweets_por_usuario.plot(kind='bar', color='coral')
plt.title('Tendencias de los tweets por usuario')
plt.xlabel('Numero de Tweets')
plt.ylabel('Numero de Tweets por usuarios')
plt.grid(True)
plt.show()
